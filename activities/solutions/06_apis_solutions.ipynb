# %%
## imports
import pandas as pd
import numpy as np
import re
import requests
import yaml


## repeated printouts
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# # 1. Example 1: no credentials; no wrapper
#
# Site: National Assessment of Education Progress (NAEP)
#
# Documentation: https://www.nationsreportcard.gov/api_documentation.aspx
#
# Base link: https://www.nationsreportcard.gov/DataService/GetAdhocData.aspx

# %% [markdown]
# ## 1.1 Query to pull some data

# %%
## using their example query of 2011 writing scores separated by gender
## based on here - https://stackoverflow.com/questions/40836749/pythonic-way-of-writing-a-single-line-long-string
## using the ( ) syntax to formulate a long
## string without linebreaks added
example_naep_query = (
'https://www.nationsreportcard.gov/'
'Dataservice/GetAdhocData.aspx?'
'type=data&subject=writing&grade=8&'
'subscale=WRIRP&variable=GENDER&jurisdiction=NP&stattype=MN:MN&Year=2011')


example_naep_query
# Out:
# 'https://www.nationsreportcard.gov/Dataservice/GetAdhocData.aspx?type=data&subject=writing&grade=8&subscale=WRIRP&variable=GENDER&jurisdiction=NP&stattype=MN:MN&Year=2011'

# %%
## use requests to call the api
naep_resp = requests.get(example_naep_query)
naep_resp
print(type(naep_resp))

## get the json contents of the response 
## here, we're assuming valid response
naep_resp_j = naep_resp.json()
naep_resp_j

## with result, turn it into a dataframe
naep_resp_d = pd.DataFrame(naep_resp_j['result'])
naep_resp_d
# Out:
# <Response [200]>
# <class 'requests.models.Response'>
# {'status': 200,
#  'serviceVersion': '6.4.2026.1',
#  'dwellTimeMS': '0',
#  'avgWebHostCPUTotalLoad': 'N/A',
#  'dataHitType': 'FROM_MEMORY',
#  'Source': 'B11A',
#  'result': [{'year': 2011,
#    'sample': 'R3',
#    'yearSampleLabel': '2011',
#    'Cohort': 2,
#    'CohortLabel': 'Grade 8',
#    'stattype': 'MN:MN',
#    'subject': 'WRI',
#    'grade': 8,
#    'scale': 'WRIRP',
#    'jurisdiction': 'NP',
#    'jurisLabel': 'National public',
#    'variable': 'GENDER',
#    'variableLabel': 'Sex',
#    'varValue': '1',
#    'varValueLabel': 'Male',
#    'value': 139.099504632971,
#    'isStatDisplayable': 1,
#    'errorFlag': 0},
#   {'year': 2011,
#    'sample': 'R3',
#    'yearSampleLabel': '2011',
#    'Cohort': 2,
#    'CohortLabel': 'Grade 8',
#    'stattype': 'MN:MN',
#    'subject': 'WRI',
#    'grade': 8,
#    'scale': 'WRIRP',
#    'jurisdiction': 'NP',
#    'jurisLabel': 'National public',
#    'variable': 'GENDER',
#    'variableLabel': 'Sex',
#    'varValue': '2',
#    'varValueLabel': 'Female',
#    'value': 158.567104984955,
#    'isStatDisplayable': 1,
#    'errorFlag': 0}]}
#    year sample yearSampleLabel  Cohort CohortLabel stattype subject  grade  \
# 0  2011     R3            2011       2     Grade 8    MN:MN     WRI      8
# 1  2011     R3            2011       2     Grade 8    MN:MN     WRI      8
#
#    scale jurisdiction       jurisLabel variable variableLabel varValue  \
# 0  WRIRP           NP  National public   GENDER           Sex        1
# 1  WRIRP           NP  National public   GENDER           Sex        2
#
#   varValueLabel       value  isStatDisplayable  errorFlag
# 0          Male  139.099505                  1          0
# 1        Female  158.567105                  1          0

# %% [markdown]
# ## 1.2 What happens if there's an error in our query?

# %%
## here's a query that from the documentation we know
## won't work since i modified year to 2025 which doesnt
## exist in the data
wrong_naep_query = (
'https://www.nationsreportcard.gov/'
'Dataservice/GetAdhocData.aspx?'
'type=data&subject=writing&grade=8&'
'subscale=WRIRP&variable=GENDER&jurisdiction=NP&stattype=MN:MN&Year=2025')

wrong_naep_query
# Out:
# 'https://www.nationsreportcard.gov/Dataservice/GetAdhocData.aspx?type=data&subject=writing&grade=8&subscale=WRIRP&variable=GENDER&jurisdiction=NP&stattype=MN:MN&Year=2025'

# %%
## use requests to call the api
naep_wrong_resp = requests.get(wrong_naep_query)
naep_wrong_resp
# Out:
# <Response [400]>

# %%
## in the case of this particular api,
## the call returns some response but
## when we try to extract the json containing
## status or results, we get in an error
#naep_wrong_resp.json() # uncomment to see error

# %%
naep_wrong_resp.text
# Out:
# '{"statusCode":400,"result": "System.Exception: The query \'SELECT DISTINCT Framework FROM Cycles WHERE Subject=\'WRI\' AND Cohort=2 AND CONVERT(VARCHAR(10),Year)+Sample IN (\'2025R3\')\' did not return exactly 1 framework. Make sure you can trend the years defined for the given subject and cohort.\r\n   at NRCDataService3.GetAdhocData.GetFramework(NDEContext& ndeContext, String subjectCode, List`1 yearSamples, String cohort) in C:\\projects\\ndecore2025\\NRCDataService2\\GetAdhocData.aspx.cs:line 2733\r\n   at NRCDataService3.GetAdhocData.PopulateBaseOrchestratorRequest() in C:\\projects\\ndecore2025\\NRCDataService2\\GetAdhocData.aspx.cs:line 2348\r\n   at NRCDataService3.GetAdhocData.ConstructRequest_Datapoint() in C:\\projects\\ndecore2025\\NRCDataService2\\GetAdhocData.aspx.cs:line 947\r\n   at NRCDataService3.GetAdhocData.Page_Load(Object sender, EventArgs e) in C:\\projects\\ndecore2025\\NRCDataService2\\GetAdhocData.aspx.cs:line 354"}'

# %% [markdown]
# ### 1.2.2 More all-purpose way of allowing remainder of calls to run: try, except

# %%
## putting it in a try; except as general error catching
try:
    results = naep_wrong_resp.json()['result']
except Exception as e:
    print('Failed to get result from API due to error:')
    print(e) # or just: pass
# Out:
# Failed to get result from API due to error:
# Invalid control character at: line 1 column 293 (char 292)

# %% [markdown]
# ### 1.2.3 Can usually also find more targeted way but that varies more across APIs

# %%
## if we wanted do more specific error catching,
## see that the status == 400 actually appears here
## so could write if else along those lines
naep_wrong_resp.text
naep_resp.text

if "System.Exception" in naep_wrong_resp.text:
    print("NAEP results not found")
# Out:
# '{"statusCode":400,"result": "System.Exception: The query \'SELECT DISTINCT Framework FROM Cycles WHERE Subject=\'WRI\' AND Cohort=2 AND CONVERT(VARCHAR(10),Year)+Sample IN (\'2025R3\')\' did not return exactly 1 framework. Make sure you can trend the years defined for the given subject and cohort.\r\n   at NRCDataService3.GetAdhocData.GetFramework(NDEContext& ndeContext, String subjectCode, List`1 yearSamples, String cohort) in C:\\projects\\ndecore2025\\NRCDataService2\\GetAdhocData.aspx.cs:line 2733\r\n   at NRCDataService3.GetAdhocData.PopulateBaseOrchestratorRequest() in C:\\projects\\ndecore2025\\NRCDataService2\\GetAdhocData.aspx.cs:line 2348\r\n   at NRCDataService3.GetAdhocData.ConstructRequest_Datapoint() in C:\\projects\\ndecore2025\\NRCDataService2\\GetAdhocData.aspx.cs:line 947\r\n   at NRCDataService3.GetAdhocData.Page_Load(Object sender, EventArgs e) in C:\\projects\\ndecore2025\\NRCDataService2\\GetAdhocData.aspx.cs:line 354"}'
# '{"status":200,"serviceVersion":"6.4.2026.1","dwellTimeMS":"0","avgWebHostCPUTotalLoad":"N/A","dataHitType":"FROM_MEMORY","Source":"B11A","result": [{"year":2011,"sample":"R3","yearSampleLabel":"2011","Cohort":2,"CohortLabel":"Grade 8","stattype":"MN:MN","subject":"WRI","grade":8,"scale":"WRIRP","jurisdiction":"NP","jurisLabel":"National public","variable":"GENDER","variableLabel":"Sex","varValue":"1","varValueLabel":"Male","value":139.099504632971,"isStatDisplayable":1,"errorFlag":0},{"year":2011,"sample":"R3","yearSampleLabel":"2011","Cohort":2,"CohortLabel":"Grade 8","stattype":"MN:MN","subject":"WRI","grade":8,"scale":"WRIRP","jurisdiction":"NP","jurisLabel":"National public","variable":"GENDER","variableLabel":"Sex","varValue":"2","varValueLabel":"Female","value":158.567104984955,"isStatDisplayable":1,"errorFlag":0}]}'
# NAEP results not found

# %% [markdown]
# ## Activity 1: writing a function to make multiple, sequential calls
#
# - Say we want to pull the data for grades 4, 8, and 12
# - How can we write a function that iterates over a list of those grades and pulls the data for each grade?
#
# **Note**: an ideal function would have arguments for each parameter in the API like subject, subscale, etc. Here we can leave those other parts constant

# %%
example_naep_query = (
'https://www.nationsreportcard.gov/'
'Dataservice/GetAdhocData.aspx?'
'type=data&subject=writing&grade=8&'
'subscale=WRIRP&variable=GENDER&jurisdiction=NP&stattype=MN:MN&Year=2011')

# %%
def naep_api_calls(grades: list,
                   baseurl = 'https://www.nationsreportcard.gov/Dataservice/GetAdhocData.aspx?',
                   query_part1 = 'type=data&subject=writing',
                   query_part3 = '&subscale=WRIRP&variable=GENDER&jurisdiction=NP&stattype=MN:MN&Year=2011'):
                       
    '''This function calls the NAEP API to get data on writing scores for the grade requested in 2011.
    
    Parameters:
        baseurl (str): default URL for NAEP or similar API
        query_part1 (str): first batch of arguments
        grades (list of int): what grades to get data on
        query_part3 (str): third batch of arguments
    Returns:
        DataFrame with the results'''
    
    dflist = []
    
    for grade in grades:
        naep_query = baseurl + query_part1  + query_part3 + ('&grade=' + str(grade))
        naep_resp = requests.get(naep_query)
        
        #if "System.Exception" in naep_resp.text:
        #    print(f"NAEP results not found for grade {str(grade)}, please try with grade in range of 1-12")
        #else:
        try:
            naep_resp_df = pd.DataFrame(naep_resp.json()['result'])
            dflist.append(naep_resp_df)
        except Exception as e:
            print("Failed to get result from API for grade {} due to error:".format(str(grade)))
            print(e)
        
    combined_result_df = pd.concat(dflist)
    
    return(combined_result_df)


naep_api_calls(grades = [4,8,12])
# Out:
# Failed to get result from API for grade 4 due to error:
# Invalid control character at: line 1 column 293 (char 292)
#    year sample yearSampleLabel  Cohort CohortLabel stattype subject  grade  \
# 0  2011     R3            2011       2     Grade 8    MN:MN     WRI      8
# 1  2011     R3            2011       2     Grade 8    MN:MN     WRI      8
# 0  2011     R3            2011       3    Grade 12    MN:MN     WRI     12
# 1  2011     R3            2011       3    Grade 12    MN:MN     WRI     12
#
#    scale jurisdiction       jurisLabel variable variableLabel varValue  \
# 0  WRIRP           NP  National public   GENDER           Sex        1
# 1  WRIRP           NP  National public   GENDER           Sex        2
# 0  WRIRP           NP  National public   GENDER           Sex        1
# 1  WRIRP           NP  National public   GENDER           Sex        2
#
#   varValueLabel       value  isStatDisplayable  errorFlag
# 0          Male  139.099505                  1          0
# 1        Female  158.567105                  1          0
# 0          Male  141.256978                  1          0
# 1        Female  155.385917                  1          0

# %% [markdown]
# # 2. Example 2: needs credentials; no wrapper

# %%
# Format example

# %%
API_KEY = "Your Key"
API_KEY = "rAZn1RX6Tr2o999Ly8EvD6ofsNGBZg3CMDsDxAwKGTEdWIi1zm9g23h_1ll5oix2Z0hSDiRloteTewU35nBqydGvoq0LngcGlZPP6LERVywiS_uc18KMmtvg9qQuZXYx"

# %%
## use documentation to define what to search
## doc: https://www.yelp.com/developers/documentation/v3/business_search
## write the query 
base_url = "https://api.yelp.com/v3/businesses/search?"
my_name = "restaurants"
my_location = "Hanover,NH,03755"
yelp_genquery = ('{base_url}'
                'term={name}'
                '&location={loc}').format(base_url = base_url,
                name = my_name,
                loc = my_location)

## use requests to call the API; here, we're
## passing it our credentials (structure varies
## by API and telling it to only return 10 results
## (max is 50 at once)
header = {'Authorization': f"Bearer {API_KEY}"}
yelp_genresp = requests.get(yelp_genquery, headers = header)
yelp_genresp

## then, look at structure of response
yelp_genjson = yelp_genresp.json()
# Out:
# <Response [200]>

# %%
yelp_genjson["businesses"]
# Out:
# [{'id': '8ybF6YyRldtZmU9jil4xlg',
#   'alias': 'mollys-restaurant-and-bar-hanover',
#   'name': "Molly's Restaurant & Bar",
#   'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/TJLrrA6z-SnPgZfrs2GQNQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/mollys-restaurant-and-bar-hanover?adjust_creative=ZmitoFfF-pb6UbUwNTC3_A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZmitoFfF-pb6UbUwNTC3_A',
#   'review_count': 582,
#   'categories': [{'alias': 'tradamerican', 'title': 'American'},
#    {'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 3.9,
#   'coordinates': {'latitude': 43.701144, 'longitude': -72.2894249},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '43 South Main St',
#    'address2': '',
#    'address3': '',
#    'city': 'Hanover',
#    'zip_code': '03755',
#    'country': 'US',
#    'state': 'NH',
#    'display_address': ['43 South Main St', 'Hanover, NH 03755']},
#   'phone': '+16036432570',
#   'display_phone': '(603) 643-2570',
#   'distance': 250.8301601841674},
#  {'id': 'XVGEEIH5rVB2QzW-qywcJw',
#   'alias': 'base-camp-cafe-hanover',
#   'name': 'Base Camp Cafe',
#   'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/tScZeoF0qVMgwNocD6_-XQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/base-camp-cafe-hanover?adjust_creative=ZmitoFfF-pb6UbUwNTC3_A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZmitoFfF-pb6UbUwNTC3_A',
#   'review_count': 264,
#   'categories': [{'alias': 'himalayan', 'title': 'Himalayan/Nepalese'}],
#   'rating': 4.4,
#   'coordinates': {'latitude': 43.700626, 'longitude': -72.2887803},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '3 Lebanon St',
#    'address2': 'Ste 13',
#    'address3': '',
#    'city': 'Hanover',
#    'zip_code': '03755',
#    'country': 'US',
#    'state': 'NH',
#    'display_address': ['3 Lebanon St', 'Ste 13', 'Hanover, NH 03755']},
#   'phone': '+16036432007',
#   'display_phone': '(603) 643-2007',
#   'distance': 196.1397581876442},
#  {'id': 'JFE0XffhpP3Bi3DQRvymVg',
#   'alias': 'little-havana-hanover',
#   'name': 'Little Havana',
#   'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/941vaRo98hcxAOpN7KICSA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/little-havana-hanover?adjust_creative=ZmitoFfF-pb6UbUwNTC3_A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZmitoFfF-pb6UbUwNTC3_A',
#   'review_count': 29,
#   'categories': [{'alias': 'cuban', 'title': 'Cuban'},
#    {'alias': 'latin', 'title': 'Latin American'}],
#   'rating': 4.9,
#   'coordinates': {'latitude': 43.700743, 'longitude': -72.287599},
#   'transactions': ['delivery', 'pickup'],
#   'location': {'address1': '15 Lebanon St',
#    'address2': '',
#    'address3': '',
#    'city': 'Hanover',
#    'zip_code': '03755',
#    'country': 'US',
#    'state': 'NH',
#    'display_address': ['15 Lebanon St', 'Hanover, NH 03755']},
#   'phone': '+18383831000',
#   'display_phone': '(838) 383-1000',
#   'distance': 102.83322895097157},
#  {'id': 'wyV_NfYn4ZOfp_sHMDPcAw',
#   'alias': 'bistro-at-six-hanover',
#   'name': 'Bistro at Six',
#   'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/i4jvssUsxa79VYVLOD3TmQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/bistro-at-six-hanover?adjust_creative=ZmitoFfF-pb6UbUwNTC3_A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZmitoFfF-pb6UbUwNTC3_A',
#   'review_count': 2,
#   'categories': [{'alias': 'lounges', 'title': 'Lounges'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#    {'alias': 'tradamerican', 'title': 'American'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 43.7001146, 'longitude': -72.2877078},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '6 E South St',
#    'address2': '',
#    'address3': '',
#    'city': 'Hanover',
#    'zip_code': '03755',
#    'country': 'US',
#    'state': 'NH',
#    'display_address': ['6 E South St', 'Hanover, NH 03755']},
#   'phone': '+16036430600',
#   'display_phone': '(603) 643-0600',
#   'distance': 198.65178837196856},
#  {'id': '5WW4g_LRwau29KyjZGLyAA',
#   'alias': 'sawtooth-kitchen-hanover',
#   'name': 'Sawtooth Kitchen',
#   'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/61MNG4d1fmE2TW1Ie_b01w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/sawtooth-kitchen-hanover?adjust_creative=ZmitoFfF-pb6UbUwNTC3_A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZmitoFfF-pb6UbUwNTC3_A',
#   'review_count': 39,
#   'categories': [{'alias': 'chickenshop', 'title': 'Chicken Shop'}],
#   'rating': 4.2,
#   'coordinates': {'latitude': 43.70158, 'longitude': -72.289641},
#   'transactions': [],
#   'location': {'address1': '33 S Main St',
#    'address2': '',
#    'address3': '',
#    'city': 'Hanover',
#    'zip_code': '03755',
#    'country': 'US',
#    'state': 'NH',
#    'display_address': ['33 S Main St', 'Hanover, NH 03755']},
#   'phone': '+16036435134',
#   'display_phone': '(603) 643-5134',
#   'distance': 242.6075518026577},
#  {'id': '1Q9gTry0GH2NFA7O398xeA',
#   'alias': 'casa-brava-tapas-hanover',
#   'name': 'Casa Brava Tapas',
#   'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/fA3__VAtCt0jkxDpd2pVNQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/casa-brava-tapas-hanover?adjust_creative=ZmitoFfF-pb6UbUwNTC3_A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZmitoFfF-pb6UbUwNTC3_A',
#   'review_count': 10,
#   'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#   'rating': 4.8,
#   'coordinates': {'latitude': 43.70019133305323,
#    'longitude': -72.28874035356495},
#   'transactions': [],
#   'location': {'address1': '6 South St',
#    'address2': '',
#    'address3': '',
#    'city': 'Hanover',
#    'zip_code': '03755',
#    'country': 'US',
#    'state': 'NH',
#    'display_address': ['6 South St', 'Hanover, NH 03755']},
#   'phone': '+16038509763',
#   'display_phone': '(603) 850-9763',
#   'distance': 202.701925304565},
#  {'id': 'KA8yhrd-ClVYMyOefXdVYg',
#   'alias': 'lous-restaurant-and-bakery-hanover',
#   'name': "Lou's Restaurant & Bakery",
#   'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/ZguQWugrd-GYMer6iX953A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/lous-restaurant-and-bakery-hanover?adjust_creative=ZmitoFfF-pb6UbUwNTC3_A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZmitoFfF-pb6UbUwNTC3_A',
#   'review_count': 454,
#   'categories': [{'alias': 'tradamerican', 'title': 'American'},
#    {'alias': 'bakeries', 'title': 'Bakeries'},
#    {'alias': 'donuts', 'title': 'Donuts'}],
#   'rating': 4.2,
#   'coordinates': {'latitude': 43.70143, 'longitude': -72.289001},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '30 S Main St',
#    'address2': '',
#    'address3': '',
#    'city': 'Hanover',
#    'zip_code': '03755',
#    'country': 'US',
#    'state': 'NH',
#    'display_address': ['30 S Main St', 'Hanover, NH 03755']},
#   'phone': '+16036433321',
#   'display_phone': '(603) 643-3321',
#   'distance': 245.07923208245205},
#  {'id': '34j_2nRCVQBTKafJvncZlg',
#   'alias': 'pine-restaurant-hanover-2',
#   'name': 'PINE Restaurant',
#   'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/c2SgURpO89OGUXP3r_sM8w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/pine-restaurant-hanover-2?adjust_creative=ZmitoFfF-pb6UbUwNTC3_A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZmitoFfF-pb6UbUwNTC3_A',
#   'review_count': 252,
#   'categories': [{'alias': 'newamerican', 'title': 'New American'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 43.7024572, 'longitude': -72.2875656},
#   'transactions': ['delivery'],
#   'price': '$$$',
#   'location': {'address1': '2 E Wheelock St',
#    'address2': '',
#    'address3': '',
#    'city': 'Hanover',
#    'zip_code': '03755',
#    'country': 'US',
#    'state': 'NH',
#    'display_address': ['2 E Wheelock St', 'Hanover, NH 03755']},
#   'phone': '+16036468000',
#   'display_phone': '(603) 646-8000',
#   'distance': 256.00429144986015},
#  {'id': 'vMyN7JL5cJExJORgIobbQg',
#   'alias': 'tuk-tuk-thai-cuisine-hanover',
#   'name': 'Tuk Tuk Thai Cuisine',
#   'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/--bUG38dWvNQ0V3f6e9iEQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/tuk-tuk-thai-cuisine-hanover?adjust_creative=ZmitoFfF-pb6UbUwNTC3_A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZmitoFfF-pb6UbUwNTC3_A',
#   'review_count': 346,
#   'categories': [{'alias': 'thai', 'title': 'Thai'}],
#   'rating': 4.2,
#   'coordinates': {'latitude': 43.702312731715395,
#    'longitude': -72.28975164840178},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '5 S Main St',
#    'address2': '',
#    'address3': '',
#    'city': 'Hanover',
#    'zip_code': '03755',
#    'country': 'US',
#    'state': 'NH',
#    'display_address': ['5 S Main St', 'Hanover, NH 03755']},
#   'phone': '+16032779192',
#   'display_phone': '(603) 277-9192',
#   'distance': 323.03674792351757},
#  {'id': 'neBEWvgHNhsXIBImCYx_6A',
#   'alias': 'murphy-s-on-the-green-hanover',
#   'name': 'Murphy’s on the Green',
#   'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/76DCQrgDN8Nqe3QKDA-opw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/murphy-s-on-the-green-hanover?adjust_creative=ZmitoFfF-pb6UbUwNTC3_A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZmitoFfF-pb6UbUwNTC3_A',
#   'review_count': 209,
#   'categories': [{'alias': 'newamerican', 'title': 'New American'},
#    {'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'pubs', 'title': 'Pubs'}],
#   'rating': 3.7,
#   'coordinates': {'latitude': 43.702, 'longitude': -72.2894949},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '11 S Main St',
#    'address2': '',
#    'address3': '',
#    'city': 'Hanover',
#    'zip_code': '03755',
#    'country': 'US',
#    'state': 'NH',
#    'display_address': ['11 S Main St', 'Hanover, NH 03755']},
#   'phone': '+16036434075',
#   'display_phone': '(603) 643-4075',
#   'distance': 295.20752311926014},
#  {'id': 'Tg8O0iPqeD_IjFGwTLqacw',
#   'alias': 'han-fusion-hanover',
#   'name': 'Han Fusion',
#   'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/CvUlbJi7Hb03cQCJErPf-A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/han-fusion-hanover?adjust_creative=ZmitoFfF-pb6UbUwNTC3_A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZmitoFfF-pb6UbUwNTC3_A',
#   'review_count': 72,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#    {'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'thai', 'title': 'Thai'}],
#   'rating': 4.2,
#   'coordinates': {'latitude': 43.700641, 'longitude': -72.2887803},
#   'transactions': ['delivery'],
#   'location': {'address1': '3 Lebanon St',
#    'address2': 'Ste 15',
#    'address3': '',
#    'city': 'Hanover',
#    'zip_code': '03755',
#    'country': 'US',
#    'state': 'NH',
#    'display_address': ['3 Lebanon St', 'Ste 15', 'Hanover, NH 03755']},
#   'phone': '+16036438888',
#   'display_phone': '(603) 643-8888',
#   'distance': 196.01251786876801},
#  {'id': 'VmMQltoybbk2XFQlWXktLw',
#   'alias': 'jewel-of-india-restaurant-hanover',
#   'name': 'Jewel of India Restaurant',
#   'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/QgUqsOWsAJoYWchRUExTaQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/jewel-of-india-restaurant-hanover?adjust_creative=ZmitoFfF-pb6UbUwNTC3_A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZmitoFfF-pb6UbUwNTC3_A',
#   'review_count': 180,
#   'categories': [{'alias': 'indpak', 'title': 'Indian'}],
#   'rating': 3.2,
#   'coordinates': {'latitude': 43.700907, 'longitude': -72.286006},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '11 Lebanon St',
#    'address2': '',
#    'address3': '',
#    'city': 'Hanover',
#    'zip_code': '03755',
#    'country': 'US',
#    'state': 'NH',
#    'display_address': ['11 Lebanon St', 'Hanover, NH 03755']},
#   'phone': '+16036432217',
#   'display_phone': '(603) 643-2217',
#   'distance': 31.564101493166955},
#  {'id': 'jAFLKiVXq9z_h4ZPy0nLMA',
#   'alias': 'the-works-café-hanover',
#   'name': 'The Works Bakery Cafe',
#   'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/FW8O21nK_jLIjDDdLb6MUQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-works-caf%C3%A9-hanover?adjust_creative=ZmitoFfF-pb6UbUwNTC3_A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZmitoFfF-pb6UbUwNTC3_A',
#   'review_count': 45,
#   'categories': [{'alias': 'bagels', 'title': 'Bagels'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#   'rating': 4.2,
#   'coordinates': {'latitude': 43.701789, 'longitude': -72.289672},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '25 S Main St',
#    'address2': '',
#    'address3': '',
#    'city': 'Hanover',
#    'zip_code': '03755',
#    'country': 'US',
#    'state': 'NH',
#    'display_address': ['25 S Main St', 'Hanover, NH 03755']},
#   'phone': '+18774192113',
#   'display_phone': '(877) 419-2113',
#   'distance': 283.3553169171081},
#  {'id': 'uZ6rg3gYgoWqFB5tOB49VQ',
#   'alias': 'tacos-y-tequila-hanover',
#   'name': 'Tacos Y Tequila',
#   'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/2tr2DorwXG0scfVi79Rz-A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/tacos-y-tequila-hanover?adjust_creative=ZmitoFfF-pb6UbUwNTC3_A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZmitoFfF-pb6UbUwNTC3_A',
#   'review_count': 51,
#   'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#    {'alias': 'bars', 'title': 'Bars'},
#    {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 43.70063761388881, 'longitude': -72.2887803},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '3 Lebanon St',
#    'address2': '',
#    'address3': '',
#    'city': 'Hanover',
#    'zip_code': '03755',
#    'country': 'US',
#    'state': 'NH',
#    'display_address': ['3 Lebanon St', 'Hanover, NH 03755']},
#   'phone': '+16032779340',
#   'display_phone': '(603) 277-9340',
#   'distance': 196.04000826741668},
#  {'id': 'GXX6xbCK1EBH9X6zJf3wVA',
#   'alias': 'sushiya-hanover-2',
#   'name': 'Sushiya',
#   'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/RUY_HGOdkXpT-mtldUrbxA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/sushiya-hanover-2?adjust_creative=ZmitoFfF-pb6UbUwNTC3_A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZmitoFfF-pb6UbUwNTC3_A',
#   'review_count': 115,
#   'categories': [{'alias': 'korean', 'title': 'Korean'},
#    {'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'japanese', 'title': 'Japanese'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 43.699737, 'longitude': -72.289326},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '72 S Main St',
#    'address2': '',
#    'address3': '',
#    'city': 'Hanover',
#    'zip_code': '03755',
#    'country': 'US',
#    'state': 'NH',
#    'display_address': ['72 S Main St', 'Hanover, NH 03755']},
#   'phone': '+16036434000',
#   'display_phone': '(603) 643-4000',
#   'distance': 265.40959563254313},
#  {'id': '1yTM59uje_iMMdwKXI7-sA',
#   'alias': 'umplebys-bakery-and-cafe-hanover',
#   'name': "Umpleby's Bakery & Cafe",
#   'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/tIaHoihBQb4TbZ55x1cxVw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/umplebys-bakery-and-cafe-hanover?adjust_creative=ZmitoFfF-pb6UbUwNTC3_A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZmitoFfF-pb6UbUwNTC3_A',
#   'review_count': 91,
#   'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#    {'alias': 'customcakes', 'title': 'Custom Cakes'}],
#   'rating': 3.1,
#   'coordinates': {'latitude': 43.69993, 'longitude': -72.288839},
#   'transactions': ['delivery'],
#   'price': '$',
#   'location': {'address1': '3 South St',
#    'address2': '',
#    'address3': '',
#    'city': 'Hanover',
#    'zip_code': '03755',
#    'country': 'US',
#    'state': 'NH',
#    'display_address': ['3 South St', 'Hanover, NH 03755']},
#   'phone': '+16036433030',
#   'display_phone': '(603) 643-3030',
#   'distance': 220.8437964167156},
#  {'id': 'Ecdu5qYM09F647Uoez99vg',
#   'alias': 'ramuntos-brick-and-brew-pizzeria-hanover',
#   'name': "Ramunto's Brick & Brew Pizzeria",
#   'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/MndDESM9D_8eSjoJI_DqKw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/ramuntos-brick-and-brew-pizzeria-hanover?adjust_creative=ZmitoFfF-pb6UbUwNTC3_A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZmitoFfF-pb6UbUwNTC3_A',
#   'review_count': 158,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 3.6,
#   'coordinates': {'latitude': 43.6998454, 'longitude': -72.2877323},
#   'transactions': ['delivery'],
#   'price': '$',
#   'location': {'address1': '9 E South St',
#    'address2': '',
#    'address3': '',
#    'city': 'Hanover',
#    'zip_code': '03755',
#    'country': 'US',
#    'state': 'NH',
#    'display_address': ['9 E South St', 'Hanover, NH 03755']},
#   'phone': '+16036439500',
#   'display_phone': '(603) 643-9500',
#   'distance': 160.30455594506685},
#  {'id': 'PACJt3XIgdu7ZfSyL7VqUg',
#   'alias': 'stinsons-village-store-hanover',
#   'name': "Stinson's Village Store",
#   'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/Sz8j_l4uRVlc1AdXRcW9IA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/stinsons-village-store-hanover?adjust_creative=ZmitoFfF-pb6UbUwNTC3_A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZmitoFfF-pb6UbUwNTC3_A',
#   'review_count': 9,
#   'categories': [{'alias': 'beer_and_wine', 'title': 'Beer, Wine & Spirits'},
#    {'alias': 'convenience', 'title': 'Convenience Stores'},
#    {'alias': 'delis', 'title': 'Delis'}],
#   'rating': 4.6,
#   'coordinates': {'latitude': 43.70144252774977,
#    'longitude': -72.29009471367995},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '2 Allen St',
#    'address2': '',
#    'address3': '',
#    'city': 'Hanover',
#    'zip_code': '03755',
#    'country': 'US',
#    'state': 'NH',
#    'display_address': ['2 Allen St', 'Hanover, NH 03755']},
#   'phone': '+16036436086',
#   'display_phone': '(603) 643-6086',
#   'distance': 310.3652426831521},
#  {'id': 'Ln8T1svyYTD3L5IUmCvbCg',
#   'alias': 'good-burger-at-pine-hanover',
#   'name': 'Good Burger at Pine',
#   'image_url': '',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/good-burger-at-pine-hanover?adjust_creative=ZmitoFfF-pb6UbUwNTC3_A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZmitoFfF-pb6UbUwNTC3_A',
#   'review_count': 1,
#   'categories': [{'alias': 'burgers', 'title': 'Burgers'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 43.70214, 'longitude': -72.28883},
#   'transactions': [],
#   'location': {'address1': '2 E Wheelock St',
#    'address2': '',
#    'address3': '',
#    'city': 'Hanover',
#    'zip_code': '03755',
#    'country': 'US',
#    'state': 'NH',
#    'display_address': ['2 E Wheelock St', 'Hanover, NH 03755']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 256.00429144986015},
#  {'id': 'DUcy-uA7S0Ml6AUk-N42MA',
#   'alias': 'bocasoca-hanover',
#   'name': 'BocaSoca',
#   'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/-h-e8HJMUmR9yDRJyeKkJA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/bocasoca-hanover?adjust_creative=ZmitoFfF-pb6UbUwNTC3_A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZmitoFfF-pb6UbUwNTC3_A',
#   'review_count': 5,
#   'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#   'rating': 2.6,
#   'coordinates': {'latitude': 43.701365, 'longitude': -72.289806},
#   'transactions': ['delivery', 'pickup'],
#   'location': {'address1': '35 S Main St',
#    'address2': '',
#    'address3': '',
#    'city': 'Hanover',
#    'zip_code': '03755',
#    'country': 'US',
#    'state': 'NH',
#    'display_address': ['35 S Main St', 'Hanover, NH 03755']},
#   'phone': '+16036430202',
#   'display_phone': '(603) 643-0202',
#   'distance': 280.5583708264489}]

# %%
## example business
yelp_genjson['businesses'][0]

## more automatic way of summarizing but things end up in lists
## within columns for things like categories
yelp_gendf = pd.DataFrame(yelp_genjson['businesses'])
yelp_gendf.head()
# Out:
# {'id': '8ybF6YyRldtZmU9jil4xlg',
#  'alias': 'mollys-restaurant-and-bar-hanover',
#  'name': "Molly's Restaurant & Bar",
#  'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/TJLrrA6z-SnPgZfrs2GQNQ/o.jpg',
#  'is_closed': False,
#  'url': 'https://www.yelp.com/biz/mollys-restaurant-and-bar-hanover?adjust_creative=ZmitoFfF-pb6UbUwNTC3_A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZmitoFfF-pb6UbUwNTC3_A',
#  'review_count': 582,
#  'categories': [{'alias': 'tradamerican', 'title': 'American'},
#   {'alias': 'burgers', 'title': 'Burgers'},
#   {'alias': 'pizza', 'title': 'Pizza'}],
#  'rating': 3.9,
#  'coordinates': {'latitude': 43.701144, 'longitude': -72.2894249},
#  'transactions': ['delivery'],
#  'price': '$$',
#  'location': {'address1': '43 South Main St',
#   'address2': '',
#   'address3': '',
#   'city': 'Hanover',
#   'zip_code': '03755',
#   'country': 'US',
#   'state': 'NH',
#   'display_address': ['43 South Main St', 'Hanover, NH 03755']},
#  'phone': '+16036432570',
#  'display_phone': '(603) 643-2570',
#  'distance': 250.8301601841674}
#                        id                              alias  \
# 0  8ybF6YyRldtZmU9jil4xlg  mollys-restaurant-and-bar-hanover
# 1  XVGEEIH5rVB2QzW-qywcJw             base-camp-cafe-hanover
# 2  JFE0XffhpP3Bi3DQRvymVg              little-havana-hanover
# 3  wyV_NfYn4ZOfp_sHMDPcAw              bistro-at-six-hanover
# 4  5WW4g_LRwau29KyjZGLyAA           sawtooth-kitchen-hanover
#
#                        name  \
# 0  Molly's Restaurant & Bar
# 1            Base Camp Cafe
# 2             Little Havana
# 3             Bistro at Six
# 4          Sawtooth Kitchen
#
#                                            image_url  is_closed  \
# 0  https://s3-media0.fl.yelpcdn.com/bphoto/TJLrrA...      False
# 1  https://s3-media0.fl.yelpcdn.com/bphoto/tScZeo...      False
# 2  https://s3-media0.fl.yelpcdn.com/bphoto/941vaR...      False
# 3  https://s3-media0.fl.yelpcdn.com/bphoto/i4jvss...      False
# 4  https://s3-media0.fl.yelpcdn.com/bphoto/61MNG4...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/mollys-restaurant-and...           582
# 1  https://www.yelp.com/biz/base-camp-cafe-hanove...           264
# 2  https://www.yelp.com/biz/little-havana-hanover...            29
# 3  https://www.yelp.com/biz/bistro-at-six-hanover...             2
# 4  https://www.yelp.com/biz/sawtooth-kitchen-hano...            39
#
#                                           categories  rating  \
# 0  [{'alias': 'tradamerican', 'title': 'American'...     3.9
# 1  [{'alias': 'himalayan', 'title': 'Himalayan/Ne...     4.4
# 2  [{'alias': 'cuban', 'title': 'Cuban'}, {'alias...     4.9
# 3  [{'alias': 'lounges', 'title': 'Lounges'}, {'a...     4.0
# 4  [{'alias': 'chickenshop', 'title': 'Chicken Sh...     4.2
#
#                                          coordinates        transactions  \
# 0  {'latitude': 43.701144, 'longitude': -72.2894249}          [delivery]
# 1  {'latitude': 43.700626, 'longitude': -72.2887803}          [delivery]
# 2   {'latitude': 43.700743, 'longitude': -72.287599}  [delivery, pickup]
# 3  {'latitude': 43.7001146, 'longitude': -72.2877...                  []
# 4    {'latitude': 43.70158, 'longitude': -72.289641}                  []
#
#   price                                           location         phone  \
# 0    $$  {'address1': '43 South Main St', 'address2': '...  +16036432570
# 1    $$  {'address1': '3 Lebanon St', 'address2': 'Ste ...  +16036432007
# 2   NaN  {'address1': '15 Lebanon St', 'address2': '', ...  +18383831000
# 3    $$  {'address1': '6 E South St', 'address2': '', '...  +16036430600
# 4   NaN  {'address1': '33 S Main St', 'address2': '', '...  +16036435134
#
#     display_phone    distance
# 0  (603) 643-2570  250.830160
# 1  (603) 643-2007  196.139758
# 2  (838) 383-1000  102.833229
# 3  (603) 643-0600  198.651788
# 4  (603) 643-5134  242.607552

# %%
## more data-specific way of summarizing
## we're doing a simple approach and just retaining
## cols that have a simple str structure
## if doing for real, would want to extract things
def clean_yelp_json(one_biz):

    ## restrict to str cols
    d_str = {key:value for key, value in one_biz.items()
             if type(value) == str}
    
    df_str = pd.DataFrame(d_str, index = [d_str['id']])
    return(df_str)

yelp_stronly = [clean_yelp_json(one_b) for one_b in yelp_genjson['businesses']]
yelp_stronly_df = pd.concat(yelp_stronly)

yelp_stronly_df.head(7)
# Out:
#                                             id  \
# 8ybF6YyRldtZmU9jil4xlg  8ybF6YyRldtZmU9jil4xlg
# XVGEEIH5rVB2QzW-qywcJw  XVGEEIH5rVB2QzW-qywcJw
# JFE0XffhpP3Bi3DQRvymVg  JFE0XffhpP3Bi3DQRvymVg
# wyV_NfYn4ZOfp_sHMDPcAw  wyV_NfYn4ZOfp_sHMDPcAw
# 5WW4g_LRwau29KyjZGLyAA  5WW4g_LRwau29KyjZGLyAA
# 1Q9gTry0GH2NFA7O398xeA  1Q9gTry0GH2NFA7O398xeA
# KA8yhrd-ClVYMyOefXdVYg  KA8yhrd-ClVYMyOefXdVYg
#
#                                                      alias  \
# 8ybF6YyRldtZmU9jil4xlg   mollys-restaurant-and-bar-hanover
# XVGEEIH5rVB2QzW-qywcJw              base-camp-cafe-hanover
# JFE0XffhpP3Bi3DQRvymVg               little-havana-hanover
# wyV_NfYn4ZOfp_sHMDPcAw               bistro-at-six-hanover
# 5WW4g_LRwau29KyjZGLyAA            sawtooth-kitchen-hanover
# 1Q9gTry0GH2NFA7O398xeA            casa-brava-tapas-hanover
# KA8yhrd-ClVYMyOefXdVYg  lous-restaurant-and-bakery-hanover
#
#                                              name  \
# 8ybF6YyRldtZmU9jil4xlg   Molly's Restaurant & Bar
# XVGEEIH5rVB2QzW-qywcJw             Base Camp Cafe
# JFE0XffhpP3Bi3DQRvymVg              Little Havana
# wyV_NfYn4ZOfp_sHMDPcAw              Bistro at Six
# 5WW4g_LRwau29KyjZGLyAA           Sawtooth Kitchen
# 1Q9gTry0GH2NFA7O398xeA           Casa Brava Tapas
# KA8yhrd-ClVYMyOefXdVYg  Lou's Restaurant & Bakery
#
#                                                                 image_url  \
# 8ybF6YyRldtZmU9jil4xlg  https://s3-media0.fl.yelpcdn.com/bphoto/TJLrrA...
# XVGEEIH5rVB2QzW-qywcJw  https://s3-media0.fl.yelpcdn.com/bphoto/tScZeo...
# JFE0XffhpP3Bi3DQRvymVg  https://s3-media0.fl.yelpcdn.com/bphoto/941vaR...
# wyV_NfYn4ZOfp_sHMDPcAw  https://s3-media0.fl.yelpcdn.com/bphoto/i4jvss...
# 5WW4g_LRwau29KyjZGLyAA  https://s3-media0.fl.yelpcdn.com/bphoto/61MNG4...
# 1Q9gTry0GH2NFA7O398xeA  https://s3-media0.fl.yelpcdn.com/bphoto/fA3__V...
# KA8yhrd-ClVYMyOefXdVYg  https://s3-media0.fl.yelpcdn.com/bphoto/ZguQWu...
#
#                                                                       url  \
# 8ybF6YyRldtZmU9jil4xlg  https://www.yelp.com/biz/mollys-restaurant-and...
# XVGEEIH5rVB2QzW-qywcJw  https://www.yelp.com/biz/base-camp-cafe-hanove...
# JFE0XffhpP3Bi3DQRvymVg  https://www.yelp.com/biz/little-havana-hanover...
# wyV_NfYn4ZOfp_sHMDPcAw  https://www.yelp.com/biz/bistro-at-six-hanover...
# 5WW4g_LRwau29KyjZGLyAA  https://www.yelp.com/biz/sawtooth-kitchen-hano...
# 1Q9gTry0GH2NFA7O398xeA  https://www.yelp.com/biz/casa-brava-tapas-hano...
# KA8yhrd-ClVYMyOefXdVYg  https://www.yelp.com/biz/lous-restaurant-and-b...
#
#                        price         phone   display_phone
# 8ybF6YyRldtZmU9jil4xlg    $$  +16036432570  (603) 643-2570
# XVGEEIH5rVB2QzW-qywcJw    $$  +16036432007  (603) 643-2007
# JFE0XffhpP3Bi3DQRvymVg   NaN  +18383831000  (838) 383-1000
# wyV_NfYn4ZOfp_sHMDPcAw    $$  +16036430600  (603) 643-0600
# 5WW4g_LRwau29KyjZGLyAA   NaN  +16036435134  (603) 643-5134
# 1Q9gTry0GH2NFA7O398xeA   NaN  +16038509763  (603) 850-9763
# KA8yhrd-ClVYMyOefXdVYg    $$  +16036433321  (603) 643-3321

# %% [markdown]
# # Activity 2: pull restaurants in a different location
#
# - Try running a business search query for your hometown or another place by constructing a query similar to `yelp_genquery` but changing the location parameter
# - Other endpoints require feeding what's called the business' fusion id into the API. Take an id from `yelp_stronly.id` and use the documentation here to pull the reviews for that business: https://www.yelp.com/developers/documentation/v3/business_reviews
# - **Challenge**: generalize the previous step by writing a function that (1) takes a list of business ids as an input, (2) calls the reviews API for each id, (3) returns the results, and (4) rowbinds all results, i.e. turns them into a single, usable DataFrame

# %%
# change location
base_url = "https://api.yelp.com/v3/businesses/search?"
my_name = "bubble tea"

my_location_tpe = "Taipei,Taiwan,03456"

yelp_genquery_tpe = ('{base_url}'
                'term={name}'
                '&location={loc}').format(base_url = base_url,
                name = my_name,
                loc = my_location_tpe)

## use requests to call the API
header = {'Authorization': f"Bearer {API_KEY}"}
yelp_genresp_tpe = requests.get(yelp_genquery_tpe, headers = header)
# yelp_genresp_tpe

## then, look at structure of response
yelp_genjson_tpe = yelp_genresp_tpe.json()

## turn JSON into usable data (DF)
yelp_gendf_tpe = pd.DataFrame(yelp_genjson_tpe['businesses'])
#list(yelp_gendf_tpe) # list columns
yelp_gendf_tpe['location1'] = yelp_gendf_tpe.location.apply(lambda loclist: loclist['address1'])
yelp_gendf_tpe[['alias', 'name', 'url', 'review_count', 'rating', 'location1', 'price']]

# Optional: Restrict to cols that are just strings
#yelp_stronly_tpe = [clean_yelp_json(one_b) for one_b in yelp_genjson_tpe['businesses']]
#yelp_stronly_tpe_df = pd.concat(yelp_stronly_tpe)

#yelp_stronly_tpe_df.head(10)
# Out:
#                              alias                       name  \
# 0                          50嵐-萬華區                        50嵐
# 1                          春水堂-信義區             Chun Shui Tang
# 2                          老虎堂-中正區                Tiger Sugar
# 3                          幸福堂-萬華區               Xing Fu Tang
# 4                          先喝道-信義區                Tao Tao Tea
# 5                    饒河街觀光夜市-松山區-2  Raohe Street Night Market
# 6                          珍煮丹-大安區                    Truedan
# 7                       樺達奶茶-中正區-2                       樺達奶茶
# 8                       士林觀光夜市-士林區        Shilin Night Market
# 9                     春水堂-台北市中正區-2             Chun Shui Tang
# 10                      樺達奶茶-大安區-3             Huada Milk Tea
# 11                         50嵐-松山區                        50嵐
# 12  odd-one-out-tea-da-an-district    ODD ONE OUT Dunnan Shop
# 13                    50嵐-台北市大安區-3                     50 Lan
# 14                          麥記-大園區                         麥記
# 15                     可不可熟成紅茶-大安區                     Kebuke
# 16                 coco都可-台北市萬華區-2                       Coco
# 17                         春水堂-中正區             Chun Shui Tang
# 18                  吉龍糖黑糖茶飲專賣店-中山區                 JLD Dragon
# 19                         伴伴堂-士林區                Half & Half
#
#                                                   url  review_count  rating  \
# 0   https://www.yelp.com/biz/50%E5%B5%90-%E8%90%AC...            22     4.2
# 1   https://www.yelp.com/biz/%E6%98%A5%E6%B0%B4%E5...            70     4.0
# 2   https://www.yelp.com/biz/%E8%80%81%E8%99%8E%E5...            19     4.7
# 3   https://www.yelp.com/biz/%E5%B9%B8%E7%A6%8F%E5...            62     4.1
# 4   https://www.yelp.com/biz/%E5%85%88%E5%96%9D%E9...             7     4.7
# 5   https://www.yelp.com/biz/%E9%A5%92%E6%B2%B3%E8...           244     4.4
# 6   https://www.yelp.com/biz/%E7%8F%8D%E7%85%AE%E4...            13     4.9
# 7   https://www.yelp.com/biz/%E6%A8%BA%E9%81%94%E5...            10     4.5
# 8   https://www.yelp.com/biz/%E5%A3%AB%E6%9E%97%E8...           264     4.1
# 9   https://www.yelp.com/biz/%E6%98%A5%E6%B0%B4%E5...            35     4.2
# 10  https://www.yelp.com/biz/%E6%A8%BA%E9%81%94%E5...             3     4.3
# 11  https://www.yelp.com/biz/50%E5%B5%90-%E6%9D%BE...             4     4.8
# 12  https://www.yelp.com/biz/odd-one-out-tea-da-an...             5     5.0
# 13  https://www.yelp.com/biz/50%E5%B5%90-%E5%8F%B0...             5     4.8
# 14  https://www.yelp.com/biz/%E9%BA%A5%E8%A8%98-%E...             1     4.0
# 15  https://www.yelp.com/biz/%E5%8F%AF%E4%B8%8D%E5...             4     4.5
# 16  https://www.yelp.com/biz/coco%E9%83%BD%E5%8F%A...             8     4.6
# 17  https://www.yelp.com/biz/%E6%98%A5%E6%B0%B4%E5...            24     4.1
# 18  https://www.yelp.com/biz/%E5%90%89%E9%BE%8D%E7...             2     4.5
# 19  https://www.yelp.com/biz/%E4%BC%B4%E4%BC%B4%E5...             2     4.5
#
#           location1 price
# 0         西寧南路48之4號     $
# 1             松壽路9號     $
# 2             南陽街1號     $
# 3            成都路29號    $$
# 4            松高路11號   NaN
# 5               饒河街     $
# 6         信義路三段200號     $
# 7         忠孝西路一段47號     $
# 8           基河路101號     $
# 9      忠孝西路一段66號B2樓    $$
# 10           通化街82號     $
# 11          長春路476號     $
# 12    敦化南路1段187巷48號   NaN
# 13  復興南路一段107巷23之3號     $
# 14           航站南路9號   NaN
# 15          師大路119號   NaN
# 16          武昌街二段4號     $
# 17        中山南路21之1號    $$
# 18          錦州街459號   NaN
# 19      天母東路8巷21之4號   NaN

# %%
# change location
base_url = "https://api.yelp.com/v3/businesses/search?"
my_name = "restaurants"

my_location_tpe = "Kuala Lumpur,Malaysia"
yelp_genquery_tpe = ('{base_url}'
                'term={name}'
                '&location={loc}').format(base_url = base_url,
                name = my_name,
                loc = my_location_tpe)

## use requests to call the API
header = {'Authorization': f"Bearer {API_KEY}"}
yelp_genresp_tpe = requests.get(yelp_genquery_tpe, headers = header)
# yelp_genresp_tpe

## then, look at structure of response
yelp_genjson_tpe = yelp_genresp_tpe.json()

## turn JSON into usable data (DF)
yelp_gendf_tpe = pd.DataFrame(yelp_genjson_tpe['businesses'])
#list(yelp_gendf_tpe) # list columns
yelp_gendf_tpe['location1'] = yelp_gendf_tpe.location.apply(lambda loclist: loclist['address1'])
yelp_gendf_tpe[['alias', 'name', 'url', 'review_count', 'rating', 'location1', 'price']]

# Optional: Restrict to cols that are just strings
#yelp_stronly_tpe = [clean_yelp_json(one_b) for one_b in yelp_genjson_tpe['businesses']]
#yelp_stronly_tpe_df = pd.concat(yelp_stronly_tpe)

#yelp_stronly_tpe_df.head(10)
# Out:
#                                        alias                         name  \
# 0              restoran-han-kee-kuala-lumpur             Restoran Han Kee
# 1     ho-kow-hainanese-kopitiam-kuala-lumpur    Ho Kow Hainanese Kopitiam
# 2             melur-dan-thyme-kuala-lumpur-2                Melur & Thyme
# 3       the-orchid-conservatory-kuala-lumpur      The Orchid Conservatory
# 4                         opium-kuala-lumpur                        Opium
# 5       restaurant-sun-huat-kee-kuala-lumpur      Restaurant Sun Huat Kee
# 6        signature-by-the-hill-petaling-jaya        Signature By The Hill
# 7       nasi-lemak-antarabangsa-kuala-lumpur      Nasi Lemak Antarabangsa
# 8              restoran-pik-wah-kuala-lumpur             Restoran Pik Wah
# 9         kedai-makanan-yut-kee-kuala-lumpur        Kedai Makanan Yut Kee
# 10     ah-loong-grilled-seafood-kuala-lumpur     Ah Loong Grilled Seafood
# 11                  la-bodega-kuala-lumpur-3                    La Bodega
# 12  yeng-kee-seafood-restaurant-kuala-lumpur  Yeng Kee Seafood Restaurant
# 13                   cantaloupe-kuala-lumpur                   Cantaloupe
# 14             the-canteen-room-kuala-lumpur             The Canteen Room
# 15          shawarma-damascus-kuala-lumpur-2            Shawarma Damascus
# 16          restoran-kam-heong-petaling-jaya           Restoran Kam Heong
# 17                food-republic-kuala-lumpur                Food Republic
# 18          sek-yuen-restaurant-kuala-lumpur          Sek Yuen Restaurant
# 19                    jibby-chow-subang-jaya                   Jibby Chow
#
#                                                   url  review_count  rating  \
# 0   https://www.yelp.com/biz/restoran-han-kee-kual...             2     5.0
# 1   https://www.yelp.com/biz/ho-kow-hainanese-kopi...            10     4.6
# 2   https://www.yelp.com/biz/melur-dan-thyme-kuala...             6     4.0
# 3   https://www.yelp.com/biz/the-orchid-conservato...             3     4.7
# 4   https://www.yelp.com/biz/opium-kuala-lumpur?ad...            32     4.4
# 5   https://www.yelp.com/biz/restaurant-sun-huat-k...             3     5.0
# 6   https://www.yelp.com/biz/signature-by-the-hill...             3     4.7
# 7   https://www.yelp.com/biz/nasi-lemak-antarabang...             3     4.7
# 8   https://www.yelp.com/biz/restoran-pik-wah-kual...             3     5.0
# 9   https://www.yelp.com/biz/kedai-makanan-yut-kee...            29     4.1
# 10  https://www.yelp.com/biz/ah-loong-grilled-seaf...             1     5.0
# 11  https://www.yelp.com/biz/la-bodega-kuala-lumpu...             6     4.0
# 12  https://www.yelp.com/biz/yeng-kee-seafood-rest...             1     4.0
# 13  https://www.yelp.com/biz/cantaloupe-kuala-lump...             8     4.9
# 14  https://www.yelp.com/biz/the-canteen-room-kual...             2     5.0
# 15  https://www.yelp.com/biz/shawarma-damascus-kua...            12     4.5
# 16  https://www.yelp.com/biz/restoran-kam-heong-pe...             5     4.6
# 17  https://www.yelp.com/biz/food-republic-kuala-l...            19     4.1
# 18  https://www.yelp.com/biz/sek-yuen-restaurant-k...            14     4.4
# 19  https://www.yelp.com/biz/jibby-chow-subang-jay...             2     4.5
#
#                                      location1 price
# 0                         N0. 42, Jalan Sultan   NaN
# 1                         1, Jalan Balai Polis   NaN
# 2                                   KL Sentral     $
# 3                           The Majestic Hotel   NaN
# 4                   50, Changkat Bukit Bintang    $$
# 5                   348, Jalan Tun Abdul Razak   NaN
# 6                    Sky Level, 1 First Avenue   $$$
# 7                       4 Jalan Raja Muda Musa     $
# 8           B1, Stadium Maba, Jalan Hang Jebat    $$
# 9                           1, Jalan Kamunting     $
# 10                 12-14, Jalan Jinjang Aman 2   NaN
# 11                    168, Jalan Bukit Bintang   $$$
# 12                           28 Jalan Jejaka 7   NaN
# 13                  Tower B, 19 Persiaran KLCC  $$$$
# 14          A-0-2 Wisma HB Megan Phileo Avenue   NaN
# 15  Jalan Bukit Bintang GF05, Yayasan Selangor   NaN
# 16                           2-20 Jalan Tengah     $
# 17                     168 Jalan Bukit Bintang     $
# 18                             315, Jalan Pudu    $$
# 19                               Jalan SS15/4G   $$$

# %%
# change location
base_url = "https://api.yelp.com/v3/businesses/search?"
my_name = "restaurants"

my_location_tpe = "London, UK"
yelp_genquery_tpe = ('{base_url}'
                'term={name}'
                '&location={loc}').format(base_url = base_url,
                name = my_name,
                loc = my_location_tpe)

## use requests to call the API
header = {'Authorization': f"Bearer {API_KEY}"}
yelp_genresp_tpe = requests.get(yelp_genquery_tpe, headers = header)
# yelp_genresp_tpe

## then, look at structure of response
yelp_genjson_tpe = yelp_genresp_tpe.json()

## turn JSON into usable data (DF)
yelp_gendf_tpe = pd.DataFrame(yelp_genjson_tpe['businesses'])
#list(yelp_gendf_tpe) # list columns
yelp_gendf_tpe['location1'] = yelp_gendf_tpe.location.apply(lambda loclist: loclist['address1'])
yelp_gendf_tpe[['alias', 'name', 'url', 'review_count', 'rating', 'location1', 'price']]

# Optional: Restrict to cols that are just strings
#yelp_stronly_tpe = [clean_yelp_json(one_b) for one_b in yelp_genjson_tpe['businesses']]
#yelp_stronly_tpe_df = pd.concat(yelp_stronly_tpe)

#yelp_stronly_tpe_df.head(10)
# Out:
#                                  alias                         name  \
# 0          the-mayfair-chippy-london-2           The Mayfair Chippy
# 1                       dishoom-london                      Dishoom
# 2                     dishoom-london-7                      Dishoom
# 3                   flat-iron-london-2                    Flat Iron
# 4                   blacklock-london-6                    Blacklock
# 5              the-victoria-paddington                 The Victoria
# 6                   mother-mash-london                  Mother Mash
# 7   the-grazing-goat-marylebone-london  The Grazing Goat Marylebone
# 8    restaurant-gordon-ramsay-london-3     Restaurant Gordon Ramsay
# 9                   the-barbary-london                  The Barbary
# 10                       scully-london                       Scully
# 11              the-alchemist-london-4                The Alchemist
# 12              the-queens-arms-london              The Queens Arms
# 13                    padella-london-3                      Padella
# 14                     fallow-london-4                       Fallow
# 15      hawksmoor-seven-dials-london-4        Hawksmoor Seven Dials
# 16            the-golden-chippy-london            The Golden Chippy
# 17                      the-ivy-london                      The Ivy
# 18              lord-wargrave-london-2                Lord Wargrave
# 19                      rules-london-2                        Rules
#
#                                                   url  review_count  rating  \
# 0   https://www.yelp.com/biz/the-mayfair-chippy-lo...           708     4.5
# 1   https://www.yelp.com/biz/dishoom-london?adjust...          3034     4.5
# 2   https://www.yelp.com/biz/dishoom-london-7?adju...           880     4.5
# 3   https://www.yelp.com/biz/flat-iron-london-2?ad...           552     4.4
# 4   https://www.yelp.com/biz/blacklock-london-6?ad...           200     4.6
# 5   https://www.yelp.com/biz/the-victoria-paddingt...           347     4.4
# 6   https://www.yelp.com/biz/mother-mash-london?ad...           651     4.3
# 7   https://www.yelp.com/biz/the-grazing-goat-mary...           318     4.2
# 8   https://www.yelp.com/biz/restaurant-gordon-ram...           283     4.3
# 9   https://www.yelp.com/biz/the-barbary-london?ad...           125     4.8
# 10  https://www.yelp.com/biz/scully-london?adjust_...            27     4.9
# 11  https://www.yelp.com/biz/the-alchemist-london-...           101     4.3
# 12  https://www.yelp.com/biz/the-queens-arms-londo...           285     4.5
# 13  https://www.yelp.com/biz/padella-london-3?adju...           337     4.5
# 14  https://www.yelp.com/biz/fallow-london-4?adjus...            56     4.1
# 15  https://www.yelp.com/biz/hawksmoor-seven-dials...           455     4.4
# 16  https://www.yelp.com/biz/the-golden-chippy-lon...           181     4.8
# 17  https://www.yelp.com/biz/the-ivy-london?adjust...           258     4.0
# 18  https://www.yelp.com/biz/lord-wargrave-london-...            52     4.6
# 19  https://www.yelp.com/biz/rules-london-2?adjust...           291     4.0
#
#                        location1 price
# 0         14 North Audley Street    ££
# 1   12 Upper Saint Martin's Lane   £££
# 2               22 Kingly Street    ££
# 3                 17 Beak Street    ££
# 4                   The Basement   £££
# 5           10a Strathearn Place    ££
# 6               26 Ganton Street    ££
# 7            6 New Quebec Street    ££
# 8         68 Royal Hospital Road  ££££
# 9                 16 Neal's Yard   £££
# 10           4 St James's Market   NaN
# 11          63-66 St Martin's Ln    ££
# 12                11 Warwick Way    ££
# 13            6 Southwark Street    ££
# 14                  52 Haymarket   £££
# 15             11 Langley Street   £££
# 16        62 Greenwich High Road    ££
# 17             1 - 5 West Street   £££
# 18          40-42 Brendon Street    ££
# 19                35 Maiden Lane   £££

# %%
# change location
base_url = "https://api.yelp.com/v3/businesses/search?"
my_name = "restaurants"

my_location_tpe = "Hanover,NH,03755"
yelp_genquery_tpe = ('{base_url}'
                'term={name}'
                '&location={loc}').format(base_url = base_url,
                name = my_name,
                loc = my_location_tpe)

## use requests to call the API
header = {'Authorization': f"Bearer {API_KEY}"}
yelp_genresp_tpe = requests.get(yelp_genquery_tpe, headers = header)
# yelp_genresp_tpe

## then, look at structure of response
yelp_genjson_tpe = yelp_genresp_tpe.json()

## turn JSON into usable data (DF)
yelp_gendf_tpe = pd.DataFrame(yelp_genjson_tpe['businesses'])
#list(yelp_gendf_tpe) # list columns
yelp_gendf_tpe['location1'] = yelp_gendf_tpe.location.apply(lambda loclist: loclist['address1'])
yelp_gendf_tpe[['alias', 'name', 'url', 'review_count', 'rating', 'location1', 'price']]

# Optional: Restrict to cols that are just strings
#yelp_stronly_tpe = [clean_yelp_json(one_b) for one_b in yelp_genjson_tpe['businesses']]
#yelp_stronly_tpe_df = pd.concat(yelp_stronly_tpe)

#yelp_stronly_tpe_df.head(10)
# Out:
#                                        alias                             name  \
# 0          mollys-restaurant-and-bar-hanover         Molly's Restaurant & Bar
# 1                     base-camp-cafe-hanover                   Base Camp Cafe
# 2                      little-havana-hanover                    Little Havana
# 3                      bistro-at-six-hanover                    Bistro at Six
# 4                   sawtooth-kitchen-hanover                 Sawtooth Kitchen
# 5                   casa-brava-tapas-hanover                 Casa Brava Tapas
# 6         lous-restaurant-and-bakery-hanover        Lou's Restaurant & Bakery
# 7                  pine-restaurant-hanover-2                  PINE Restaurant
# 8               tuk-tuk-thai-cuisine-hanover             Tuk Tuk Thai Cuisine
# 9                         han-fusion-hanover                       Han Fusion
# 10             murphy-s-on-the-green-hanover            Murphy’s on the Green
# 11         jewel-of-india-restaurant-hanover        Jewel of India Restaurant
# 12                    the-works-café-hanover            The Works Bakery Cafe
# 13                   tacos-y-tequila-hanover                  Tacos Y Tequila
# 14  ramuntos-brick-and-brew-pizzeria-hanover  Ramunto's Brick & Brew Pizzeria
# 15                         sushiya-hanover-2                          Sushiya
# 16          umplebys-bakery-and-cafe-hanover          Umpleby's Bakery & Cafe
# 17            stinsons-village-store-hanover          Stinson's Village Store
# 18                          bocasoca-hanover                         BocaSoca
# 19               good-burger-at-pine-hanover              Good Burger at Pine
#
#                                                   url  review_count  rating  \
# 0   https://www.yelp.com/biz/mollys-restaurant-and...           582     3.9
# 1   https://www.yelp.com/biz/base-camp-cafe-hanove...           264     4.4
# 2   https://www.yelp.com/biz/little-havana-hanover...            30     4.9
# 3   https://www.yelp.com/biz/bistro-at-six-hanover...             2     4.0
# 4   https://www.yelp.com/biz/sawtooth-kitchen-hano...            39     4.2
# 5   https://www.yelp.com/biz/casa-brava-tapas-hano...             9     4.8
# 6   https://www.yelp.com/biz/lous-restaurant-and-b...           454     4.2
# 7   https://www.yelp.com/biz/pine-restaurant-hanov...           252     3.5
# 8   https://www.yelp.com/biz/tuk-tuk-thai-cuisine-...           346     4.2
# 9   https://www.yelp.com/biz/han-fusion-hanover?ad...            72     4.2
# 10  https://www.yelp.com/biz/murphy-s-on-the-green...           209     3.7
# 11  https://www.yelp.com/biz/jewel-of-india-restau...           180     3.2
# 12  https://www.yelp.com/biz/the-works-caf%C3%A9-h...            45     4.2
# 13  https://www.yelp.com/biz/tacos-y-tequila-hanov...            51     3.0
# 14  https://www.yelp.com/biz/ramuntos-brick-and-br...           158     3.6
# 15  https://www.yelp.com/biz/sushiya-hanover-2?adj...           115     3.5
# 16  https://www.yelp.com/biz/umplebys-bakery-and-c...            91     3.1
# 17  https://www.yelp.com/biz/stinsons-village-stor...             9     4.6
# 18  https://www.yelp.com/biz/bocasoca-hanover?adju...             5     2.6
# 19  https://www.yelp.com/biz/good-burger-at-pine-h...             1     4.0
#
#            location1 price
# 0   43 South Main St    $$
# 1       3 Lebanon St    $$
# 2      15 Lebanon St   NaN
# 3       6 E South St    $$
# 4       33 S Main St   NaN
# 5         6 South St   NaN
# 6       30 S Main St    $$
# 7    2 E Wheelock St   $$$
# 8        5 S Main St    $$
# 9       3 Lebanon St   NaN
# 10      11 S Main St    $$
# 11     11 Lebanon St    $$
# 12      25 S Main St    $$
# 13      3 Lebanon St    $$
# 14      9 E South St     $
# 15      72 S Main St    $$
# 16        3 South St     $
# 17        2 Allen St     $
# 18      35 S Main St   NaN
# 19   2 E Wheelock St   NaN

# %%
yelp_gendf_tpe.iloc[8].id
# Out:
# 'vMyN7JL5cJExJORgIobbQg'

# %%
# Get one random business
one_biz = yelp_stronly_df.sample()[['name', 'id']]
one_biz = yelp_gendf_tpe.iloc[8]

# %%
API_KEY = "rAZn1RX6Tr2o999Ly8EvD6ofsNGBZg3CMDsDxAwKGTEdWIi1zm9g23h_1ll5oix2Z0hSDiRloteTewU35nBqydGvoq0LngcGlZPP6LERVywiS_uc18KMmtvg9qQuZXYx"
url = "https://api.yelp.com/v3/businesses/Ecdu5qYM09F647Uoez99vg/reviews?"
header = {'Authorization': f'Bearer {API_KEY}'}
response = requests.get(url, headers=header)
print(response.text)
# Out:
# {"reviews": [{"id": "qUGeiKnzJaY4ldELiyUxVA", "url": "https://www.yelp.com/biz/ramuntos-brick-and-brew-pizzeria-hanover?adjust_creative=ZmitoFfF-pb6UbUwNTC3_A&hrid=qUGeiKnzJaY4ldELiyUxVA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=ZmitoFfF-pb6UbUwNTC3_A", "text": "The famous garlic knot pizza is a must try. My friend and I split a large (okay... way too big for 2 lol) and we both could barely finish 2 slices each...", "rating": 4.0, "time_created": "2026-06-26 11:48:37", "user": {"id": "kYf0AgTRNfhV6giPT3anpQ", "profile_url": "https://www.yelp.com/user_details?userid=kYf0AgTRNfhV6giPT3anpQ", "image_url": "https://s3-media0.fl.yelpcdn.com/photo/4-DvlQkWB00d-C7hfDpK2w/o.jpg", "name": "Cleo G."}}, {"id": "KMBiy0t5YTnmvLMR2i60rA", "url": "https://www.yelp.com/biz/ramuntos-brick-and-brew-pizzeria-hanover?adjust_creative=ZmitoFfF-pb6UbUwNTC3_A&hrid=KMBiy0t5YTnmvLMR2i60rA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=ZmitoFfF-pb6UbUwNTC3_A", "text": "I order online the meditterran pizza added shrimp. I should have left them off. No flavor what so ever. Just threw cold shrimp and pizza and baked. I guess...", "rating": 3.0, "time_created": "2025-12-31 10:16:26", "user": {"id": "0G71iWXvXqibG9Lzrwg8Gg", "profile_url": "https://www.yelp.com/user_details?userid=0G71iWXvXqibG9Lzrwg8Gg", "image_url": "https://s3-media0.fl.yelpcdn.com/photo/gejQv2RVbe3T6ESVAacJZA/o.jpg", "name": "Wan G."}}, {"id": "j18Xzk5jvO4g-6E9cuxHig", "url": "https://www.yelp.com/biz/ramuntos-brick-and-brew-pizzeria-hanover?adjust_creative=ZmitoFfF-pb6UbUwNTC3_A&hrid=j18Xzk5jvO4g-6E9cuxHig&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=ZmitoFfF-pb6UbUwNTC3_A", "text": "Slices up!!!! \n\nSolid Hanover pizza spot for quick by the slice pizza on the go\n\nPro tip: Thursday's after 8pm they have beer and slice specials...", "rating": 3.0, "time_created": "2025-05-25 09:28:07", "user": {"id": "120Icn9O5C-Xj8pyYsU1MQ", "profile_url": "https://www.yelp.com/user_details?userid=120Icn9O5C-Xj8pyYsU1MQ", "image_url": "https://s3-media0.fl.yelpcdn.com/photo/JX98f8zdJHiC1NbXH7kiBg/o.jpg", "name": "Aleksandar K."}}], "total": 158, "possible_languages": ["en"]}

# %%
response.text
# Out:
# '{"reviews": [{"id": "8I8ALslMWvOQmd7AnO4N8w", "url": "https://www.yelp.com/biz/the-shed-restaurant-plainview-plainview?adjust_creative=AYAiHNSGxz_RRHzq3cO46w&hrid=8I8ALslMWvOQmd7AnO4N8w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=AYAiHNSGxz_RRHzq3cO46w", "text": "I LOVE THE SHED!\\n\\nAny location doesn\'t matter my experience has blown me away and left me satisfied.\\n\\nThe grilled chicken entree was better than my grilled...", "rating": 5, "time_created": "2023-09-23 14:26:01", "user": {"id": "HOxaVDup_Ctag_npGDdF0A", "profile_url": "https://www.yelp.com/user_details?userid=HOxaVDup_Ctag_npGDdF0A", "image_url": "https://s3-media3.fl.yelpcdn.com/photo/P78IjRv3JfpOcjE0T1dgqw/o.jpg", "name": "Emily B."}}, {"id": "sPyEsPtJz48wyOd3DIrtGA", "url": "https://www.yelp.com/biz/the-shed-restaurant-plainview-plainview?adjust_creative=AYAiHNSGxz_RRHzq3cO46w&hrid=sPyEsPtJz48wyOd3DIrtGA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=AYAiHNSGxz_RRHzq3cO46w", "text": "A small group of friends and I did outdoor dining here. The set up was lovely and interior was spacious, with white brick walls and beautiful artistic mural...", "rating": 4, "time_created": "2023-10-09 14:54:07", "user": {"id": "RJH925_Ci598EuRx9JoGwA", "profile_url": "https://www.yelp.com/user_details?userid=RJH925_Ci598EuRx9JoGwA", "image_url": "https://s3-media2.fl.yelpcdn.com/photo/24yQpxA_Omp7j4NFVyZp2A/o.jpg", "name": "Kathy X."}}, {"id": "kQkiDuuxQI6yLH59FiGuxw", "url": "https://www.yelp.com/biz/the-shed-restaurant-plainview-plainview?adjust_creative=AYAiHNSGxz_RRHzq3cO46w&hrid=kQkiDuuxQI6yLH59FiGuxw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=AYAiHNSGxz_RRHzq3cO46w", "text": "I always go right when they open to beat the lunch crowd, especially since they do not take reservations. Some servers are better than others and there is...", "rating": 4, "time_created": "2023-09-26 07:12:01", "user": {"id": "55DO2OSV4-nZhy0fvyxxbA", "profile_url": "https://www.yelp.com/user_details?userid=55DO2OSV4-nZhy0fvyxxbA", "image_url": "https://s3-media4.fl.yelpcdn.com/photo/ZDVfT1A7YgqDA5H8ddq_Ag/o.jpg", "name": "Annie Y."}}], "total": 248, "possible_languages": ["en"]}'

# %%
one_biz.id
# Out:
# 'vMyN7JL5cJExJORgIobbQg'

# %%
yelp_gendf_tpe
# Out:
#                         id                               alias  \
# 0   Vaq49W0ubGjuIc4h5_qQ0w         the-mayfair-chippy-london-2
# 1   oK_SLmmAVQg3meguh7LrIA                      dishoom-london
# 2   mc1KLbA1Sy4kUTKo0ZEeRQ                    dishoom-london-7
# 3   qhbCUUn1CM27dvTPUwvAUA                  flat-iron-london-2
# 4   iqzQ-rPbALZWPdhNksIRRw                  blacklock-london-6
# 5   teXPunKtpwj0NuttvPYhyQ             the-victoria-paddington
# 6   IBV7BsXnv2gX68nWUARhjw                  mother-mash-london
# 7   bJiVADMSTEKj0MjqiLrOPA  the-grazing-goat-marylebone-london
# 8   b8u_D0Qlp0-nqSC6O2fMNw   restaurant-gordon-ramsay-london-3
# 9   ggwDV5tRXMfQJvH2-yZVug                  the-barbary-london
# 10  zcBN6thsPRPkbqHc4lv3tg                       scully-london
# 11  usivBNSMnBY5awP1IHU39A              the-alchemist-london-4
# 12  Wjgxl0lSp_FRtzecbJ4FZQ              the-queens-arms-london
# 13  KzYd2EaFvmu63wqTIektSA                    padella-london-3
# 14  p3ylXcd-SneA_piJIcCtjA                     fallow-london-4
# 15  0B-ag3J18TatG9H9EQohGg      hawksmoor-seven-dials-london-4
# 16  lg0ZQJDQeHN_5Ela7ypyiw            the-golden-chippy-london
# 17  75-HeBBB391Np6T7GdJ5xQ                      the-ivy-london
# 18  KIlT_VLXVsTfNRTFioHcIQ              lord-wargrave-london-2
# 19  mn9JQh5w5I9YGXqHn0PbfQ                      rules-london-2
#
#                            name  \
# 0            The Mayfair Chippy
# 1                       Dishoom
# 2                       Dishoom
# 3                     Flat Iron
# 4                     Blacklock
# 5                  The Victoria
# 6                   Mother Mash
# 7   The Grazing Goat Marylebone
# 8      Restaurant Gordon Ramsay
# 9                   The Barbary
# 10                       Scully
# 11                The Alchemist
# 12              The Queens Arms
# 13                      Padella
# 14                       Fallow
# 15        Hawksmoor Seven Dials
# 16            The Golden Chippy
# 17                      The Ivy
# 18                Lord Wargrave
# 19                        Rules
#
#                                             image_url  is_closed  \
# 0   https://s3-media0.fl.yelpcdn.com/bphoto/jso_On...      False
# 1   https://s3-media0.fl.yelpcdn.com/bphoto/66NkSC...      False
# 2   https://s3-media0.fl.yelpcdn.com/bphoto/eFlLZm...      False
# 3   https://s3-media0.fl.yelpcdn.com/bphoto/J1jdhH...      False
# 4   https://s3-media0.fl.yelpcdn.com/bphoto/9gWBBu...      False
# 5   https://s3-media0.fl.yelpcdn.com/bphoto/hdkRbA...      False
# 6   https://s3-media0.fl.yelpcdn.com/bphoto/SdN6R9...      False
# 7   https://s3-media0.fl.yelpcdn.com/bphoto/elL2rh...      False
# 8   https://s3-media0.fl.yelpcdn.com/bphoto/aF5kqF...      False
# 9   https://s3-media0.fl.yelpcdn.com/bphoto/veGpbO...      False
# 10  https://s3-media0.fl.yelpcdn.com/bphoto/s9G81U...      False
# 11  https://s3-media0.fl.yelpcdn.com/bphoto/zw5bvp...      False
# 12  https://s3-media0.fl.yelpcdn.com/bphoto/-aZQ5i...      False
# 13  https://s3-media0.fl.yelpcdn.com/bphoto/ufdG5F...      False
# 14  https://s3-media0.fl.yelpcdn.com/bphoto/E5N8B8...      False
# 15  https://s3-media0.fl.yelpcdn.com/bphoto/OeGYi_...      False
# 16  https://s3-media0.fl.yelpcdn.com/bphoto/ccl-uG...      False
# 17  https://s3-media0.fl.yelpcdn.com/bphoto/hzbeaZ...      False
# 18  https://s3-media0.fl.yelpcdn.com/bphoto/CCZkN8...      False
# 19  https://s3-media0.fl.yelpcdn.com/bphoto/pdhyri...      False
#
#                                                   url  review_count  \
# 0   https://www.yelp.com/biz/the-mayfair-chippy-lo...           708
# 1   https://www.yelp.com/biz/dishoom-london?adjust...          3034
# 2   https://www.yelp.com/biz/dishoom-london-7?adju...           880
# 3   https://www.yelp.com/biz/flat-iron-london-2?ad...           552
# 4   https://www.yelp.com/biz/blacklock-london-6?ad...           200
# 5   https://www.yelp.com/biz/the-victoria-paddingt...           347
# 6   https://www.yelp.com/biz/mother-mash-london?ad...           651
# 7   https://www.yelp.com/biz/the-grazing-goat-mary...           318
# 8   https://www.yelp.com/biz/restaurant-gordon-ram...           283
# 9   https://www.yelp.com/biz/the-barbary-london?ad...           125
# 10  https://www.yelp.com/biz/scully-london?adjust_...            27
# 11  https://www.yelp.com/biz/the-alchemist-london-...           101
# 12  https://www.yelp.com/biz/the-queens-arms-londo...           285
# 13  https://www.yelp.com/biz/padella-london-3?adju...           337
# 14  https://www.yelp.com/biz/fallow-london-4?adjus...            56
# 15  https://www.yelp.com/biz/hawksmoor-seven-dials...           455
# 16  https://www.yelp.com/biz/the-golden-chippy-lon...           181
# 17  https://www.yelp.com/biz/the-ivy-london?adjust...           258
# 18  https://www.yelp.com/biz/lord-wargrave-london-...            52
# 19  https://www.yelp.com/biz/rules-london-2?adjust...           291
#
#                                            categories  rating  \
# 0   [{'alias': 'fishnchips', 'title': 'Fish & Chip...     4.5
# 1            [{'alias': 'indpak', 'title': 'Indian'}]     4.5
# 2            [{'alias': 'indpak', 'title': 'Indian'}]     4.5
# 3        [{'alias': 'steak', 'title': 'Steakhouses'}]     4.4
# 4   [{'alias': 'british', 'title': 'British'}, {'a...     4.6
# 5   [{'alias': 'pubs', 'title': 'Pubs'}, {'alias':...     4.4
# 6          [{'alias': 'british', 'title': 'British'}]     4.3
# 7   [{'alias': 'gastropubs', 'title': 'Gastropubs'...     4.2
# 8   [{'alias': 'french', 'title': 'French'}, {'ali...     4.3
# 9   [{'alias': 'mideastern', 'title': 'Middle East...     4.8
# 10         [{'alias': 'british', 'title': 'British'}]     4.9
# 11  [{'alias': 'restaurants', 'title': 'Restaurant...     4.3
# 12  [{'alias': 'british', 'title': 'British'}, {'a...     4.5
# 13         [{'alias': 'italian', 'title': 'Italian'}]     4.5
# 14  [{'alias': 'british', 'title': 'British'}, {'a...     4.1
# 15  [{'alias': 'british', 'title': 'British'}, {'a...     4.4
# 16  [{'alias': 'fishnchips', 'title': 'Fish & Chip...     4.8
# 17  [{'alias': 'british', 'title': 'British'}, {'a...     4.0
# 18  [{'alias': 'pubs', 'title': 'Pubs'}, {'alias':...     4.6
# 19  [{'alias': 'british', 'title': 'British'}, {'a...     4.0
#
#                                           coordinates transactions price  \
# 0   {'latitude': 51.5131345, 'longitude': -0.1533961}           []    ££
# 1   {'latitude': 51.512447030091, 'longitude': -0....           []   £££
# 2     {'latitude': 51.513087, 'longitude': -0.139767}           []    ££
# 3     {'latitude': 51.51212, 'longitude': -0.1384008}           []    ££
# 4     {'latitude': 51.511687, 'longitude': -0.134762}           []   £££
# 5   {'latitude': 51.51350403679, 'longitude': -0.1...           []    ££
# 6     {'latitude': 51.512935, 'longitude': -0.139414}           []    ££
# 7   {'latitude': 51.515378341447, 'longitude': -0....           []    ££
# 8     {'latitude': 51.485833, 'longitude': -0.161966}           []  ££££
# 9   {'latitude': 51.5144480132327, 'longitude': -0...           []   £££
# 10    {'latitude': 51.508673, 'longitude': -0.133049}           []   NaN
# 11  {'latitude': 51.5112707779066, 'longitude': -0...           []    ££
# 12  {'latitude': 51.4925789, 'longitude': -0.1392194}           []    ££
# 13  {'latitude': 51.5051451, 'longitude': -0.0899515}           []    ££
# 14       {'latitude': 51.5093, 'longitude': -0.13291}           []   £££
# 15  {'latitude': 51.5134998914001, 'longitude': -0...           []   £££
# 16    {'latitude': 51.475864, 'longitude': -0.018518}           []    ££
# 17    {'latitude': 51.512814, 'longitude': -0.128013}           []   £££
# 18  {'latitude': 51.5181076, 'longitude': -0.1657013}           []    ££
# 19  {'latitude': 51.5108207, 'longitude': -0.1232501}           []   £££
#
#                                              location          phone  \
# 0   {'address1': '14 North Audley Street', 'addres...  +442077412233
# 1   {'address1': '12 Upper Saint Martin's Lane', '...  +442074209320
# 2   {'address1': '22 Kingly Street', 'address2': '...  +442074209322
# 3   {'address1': '17 Beak Street', 'address2': 'So...
# 4   {'address1': 'The Basement', 'address2': '24 G...  +442034416996
# 5   {'address1': '10a Strathearn Place', 'address2...  +442077241191
# 6   {'address1': '26 Ganton Street', 'address2': '...  +442074949644
# 7   {'address1': '6 New Quebec Street', 'address2'...  +442077247243
# 8   {'address1': '68 Royal Hospital Road', 'addres...  +442073524441
# 9   {'address1': '16 Neal's Yard', 'address2': 'Se...
# 10  {'address1': '4 St James's Market', 'address2'...  +442039116840
# 11  {'address1': '63-66 St Martin's Ln', 'address2...  +442072402002
# 12  {'address1': '11 Warwick Way', 'address2': 'Pi...  +442039859446
# 13  {'address1': '6 Southwark Street', 'address2':...
# 14  {'address1': '52 Haymarket', 'address2': '', '...  +442080171788
# 15  {'address1': '11 Langley Street', 'address2': ...  +442074209390
# 16  {'address1': '62 Greenwich High Road', 'addres...  +442086924333
# 17  {'address1': '1 - 5 West Street', 'address2': ...  +442078364751
# 18  {'address1': '40-42 Brendon Street', 'address2...  +442077230559
# 19  {'address1': '35 Maiden Lane', 'address2': '',...  +442078365314
#
#        display_phone     distance                     location1
# 0   +44 20 7741 2233  1205.537933        14 North Audley Street
# 1   +44 20 7420 9320   626.567432  12 Upper Saint Martin's Lane
# 2   +44 20 7420 9322   262.732936              22 Kingly Street
# 3                      191.051478                17 Beak Street
# 4   +44 20 3441 6996   162.359136                  The Basement
# 5   +44 20 7724 1191  2438.157244          10a Strathearn Place
# 6   +44 20 7494 9644   233.422396              26 Ganton Street
# 7   +44 20 7724 7243  1563.977535           6 New Quebec Street
# 8   +44 20 7352 4441  3509.749628        68 Royal Hospital Road
# 9                      694.460322                16 Neal's Yard
# 10  +44 20 3911 6840   515.512564           4 St James's Market
# 11  +44 20 7240 2002   651.753104          63-66 St Martin's Ln
# 12  +44 20 3985 9446  2270.086987                11 Warwick Way
# 13                    3301.063422            6 Southwark Street
# 14  +44 20 8017 1788   455.090878                  52 Haymarket
# 15  +44 20 7420 9390   715.805011             11 Langley Street
# 16  +44 20 8692 4333  9116.786047        62 Greenwich High Road
# 17  +44 20 7836 4751   551.358332             1 - 5 West Street
# 18  +44 20 7723 0559  2138.416148          40-42 Brendon Street
# 19  +44 20 7836 5314   916.641128                35 Maiden Lane

# %%
# look at reviews of business with this id
base_url_reviews = f'https://api.yelp.com/v3/businesses/{one_biz.id}/reviews'
yelp_genquery_reviews = (base_url_reviews)

## use requests to call the API
header = {'Authorization': f"Bearer {API_KEY}"}
yelp_genresp_reviews = requests.get(yelp_genquery_reviews, headers = header)
yelp_genresp_reviews

## then, look at structure of response
yelp_genjson_reviews = yelp_genresp_reviews.json()
yelp_genjson_reviews
# Out:
# <Response [200]>
# {'reviews': [{'id': 'f5-39FJC7UbTb2rtBIbhyg',
#    'url': 'https://www.yelp.com/biz/tuk-tuk-thai-cuisine-hanover?adjust_creative=ZmitoFfF-pb6UbUwNTC3_A&hrid=f5-39FJC7UbTb2rtBIbhyg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=ZmitoFfF-pb6UbUwNTC3_A',
#    'text': 'Special curry avocado curry with chicken     Appetizer    Very very good portion  sized good',
#    'rating': 5.0,
#    'time_created': '2026-02-03 18:15:32',
#    'user': {'id': 'sezXZQlcHeTb2CxMlxZKXA',
#     'profile_url': 'https://www.yelp.com/user_details?userid=sezXZQlcHeTb2CxMlxZKXA',
#     'image_url': 'https://s3-media0.fl.yelpcdn.com/photo/gOpS778gW7ePiE4KaZ1d7A/o.jpg',
#     'name': 'George G.'}},
#   {'id': 'wCdsj52xvhr-T8jU5y2xdg',
#    'url': 'https://www.yelp.com/biz/tuk-tuk-thai-cuisine-hanover?adjust_creative=ZmitoFfF-pb6UbUwNTC3_A&hrid=wCdsj52xvhr-T8jU5y2xdg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=ZmitoFfF-pb6UbUwNTC3_A',
#    'text': '3.5 Stars. Decent Thai flavors. We got the Pad Ka Pao with Beef, Tom Yum Soup with Chicken, Tom Kha Soup with Tofu, and Crab Fried Rice. The portion sizes...',
#    'rating': 4.0,
#    'time_created': '2026-03-22 08:04:09',
#    'user': {'id': 'tw0-8I8Ix9gPhBl7C3vHRg',
#     'profile_url': 'https://www.yelp.com/user_details?userid=tw0-8I8Ix9gPhBl7C3vHRg',
#     'image_url': 'https://s3-media0.fl.yelpcdn.com/photo/4c1ap7GxejdVHV5O6MCoUg/o.jpg',
#     'name': 'Winston L.'}},
#   {'id': 'qF0MR39zWXZMnIeel3xPpg',
#    'url': 'https://www.yelp.com/biz/tuk-tuk-thai-cuisine-hanover?adjust_creative=ZmitoFfF-pb6UbUwNTC3_A&hrid=qF0MR39zWXZMnIeel3xPpg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=ZmitoFfF-pb6UbUwNTC3_A',
#    'text': "The food here is absolutely delicious. It's definitely one of the best restaurants on campus. The vibe is chill and can be friendly or romantic. Service can...",
#    'rating': 5.0,
#    'time_created': '2025-04-12 13:01:22',
#    'user': {'id': 'xS2yQl-RKvurfQTwx5w_Mg',
#     'profile_url': 'https://www.yelp.com/user_details?userid=xS2yQl-RKvurfQTwx5w_Mg',
#     'image_url': 'https://s3-media0.fl.yelpcdn.com/photo/QSHLkKjP98Vz28MyENiBKg/o.jpg',
#     'name': 'Lismarie G.'}}],
#  'total': 340,
#  'possible_languages': ['en', 'fr']}

# %%
yelp_genjson_reviews['reviews']
# Out:
# [{'id': 'UpqByKb8iBIFzYvFmvtt0A',
#   'url': 'https://www.yelp.com/biz/ramuntos-brick-and-brew-pizzeria-hanover?adjust_creative=AYAiHNSGxz_RRHzq3cO46w&hrid=UpqByKb8iBIFzYvFmvtt0A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=AYAiHNSGxz_RRHzq3cO46w',
#   'text': "Best pizza ever from this townie. Even other towns nearby... still can't get me to fully change my mind on how this place has the best sauce, pies, and noms...",
#   'rating': 5,
#   'time_created': '2023-08-08 06:53:00',
#   'user': {'id': 'kgAiZU60RefGdjkeRdi0pA',
#    'profile_url': 'https://www.yelp.com/user_details?userid=kgAiZU60RefGdjkeRdi0pA',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/photo/lLzLXgaHEtgaPwhPVfs74g/o.jpg',
#    'name': 'Mia A.'}},
#  {'id': 'Yxj8gWX2isGf0-DVBPq67A',
#   'url': 'https://www.yelp.com/biz/ramuntos-brick-and-brew-pizzeria-hanover?adjust_creative=AYAiHNSGxz_RRHzq3cO46w&hrid=Yxj8gWX2isGf0-DVBPq67A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=AYAiHNSGxz_RRHzq3cO46w',
#   'text': "Food's great. I've never eaten in the restaurant but I've been inside to pick stuff up, and it looks like a pleasant place. Remarkably good menu selection...",
#   'rating': 5,
#   'time_created': '2023-07-16 06:33:50',
#   'user': {'id': 'u4xo8pAidfxkySAqdLCMzw',
#    'profile_url': 'https://www.yelp.com/user_details?userid=u4xo8pAidfxkySAqdLCMzw',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/photo/Hgwrx7swzNs7m28FBwq26Q/o.jpg',
#    'name': 'Izzy T.'}},
#  {'id': 'v7yO_1BBXGmVtPIYM2Pt2g',
#   'url': 'https://www.yelp.com/biz/ramuntos-brick-and-brew-pizzeria-hanover?adjust_creative=AYAiHNSGxz_RRHzq3cO46w&hrid=v7yO_1BBXGmVtPIYM2Pt2g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=AYAiHNSGxz_RRHzq3cO46w',
#   'text': "Unfortunately, I have had a few shockingly bad service experiences here. I don't appreciate being treated like a nuisance when I'm just ordering my food. I...",
#   'rating': 1,
#   'time_created': '2023-08-14 16:55:57',
#   'user': {'id': 'QqgErTzfEOH5KdcW387Mow',
#    'profile_url': 'https://www.yelp.com/user_details?userid=QqgErTzfEOH5KdcW387Mow',
#    'image_url': None,
#    'name': 'D. W.'}}]

# %%
yelp_genjson_reviews
# Out:
# {'reviews': [{'id': 'UpqByKb8iBIFzYvFmvtt0A',
#    'url': 'https://www.yelp.com/biz/ramuntos-brick-and-brew-pizzeria-hanover?adjust_creative=AYAiHNSGxz_RRHzq3cO46w&hrid=UpqByKb8iBIFzYvFmvtt0A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=AYAiHNSGxz_RRHzq3cO46w',
#    'text': "Best pizza ever from this townie. Even other towns nearby... still can't get me to fully change my mind on how this place has the best sauce, pies, and noms...",
#    'rating': 5,
#    'time_created': '2023-08-08 06:53:00',
#    'user': {'id': 'kgAiZU60RefGdjkeRdi0pA',
#     'profile_url': 'https://www.yelp.com/user_details?userid=kgAiZU60RefGdjkeRdi0pA',
#     'image_url': 'https://s3-media2.fl.yelpcdn.com/photo/lLzLXgaHEtgaPwhPVfs74g/o.jpg',
#     'name': 'Mia A.'}},
#   {'id': 'Yxj8gWX2isGf0-DVBPq67A',
#    'url': 'https://www.yelp.com/biz/ramuntos-brick-and-brew-pizzeria-hanover?adjust_creative=AYAiHNSGxz_RRHzq3cO46w&hrid=Yxj8gWX2isGf0-DVBPq67A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=AYAiHNSGxz_RRHzq3cO46w',
#    'text': "Food's great. I've never eaten in the restaurant but I've been inside to pick stuff up, and it looks like a pleasant place. Remarkably good menu selection...",
#    'rating': 5,
#    'time_created': '2023-07-16 06:33:50',
#    'user': {'id': 'u4xo8pAidfxkySAqdLCMzw',
#     'profile_url': 'https://www.yelp.com/user_details?userid=u4xo8pAidfxkySAqdLCMzw',
#     'image_url': 'https://s3-media2.fl.yelpcdn.com/photo/Hgwrx7swzNs7m28FBwq26Q/o.jpg',
#     'name': 'Izzy T.'}},
#   {'id': 'v7yO_1BBXGmVtPIYM2Pt2g',
#    'url': 'https://www.yelp.com/biz/ramuntos-brick-and-brew-pizzeria-hanover?adjust_creative=AYAiHNSGxz_RRHzq3cO46w&hrid=v7yO_1BBXGmVtPIYM2Pt2g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=AYAiHNSGxz_RRHzq3cO46w',
#    'text': "Unfortunately, I have had a few shockingly bad service experiences here. I don't appreciate being treated like a nuisance when I'm just ordering my food. I...",
#    'rating': 1,
#    'time_created': '2023-08-14 16:55:57',
#    'user': {'id': 'QqgErTzfEOH5KdcW387Mow',
#     'profile_url': 'https://www.yelp.com/user_details?userid=QqgErTzfEOH5KdcW387Mow',
#     'image_url': None,
#     'name': 'D. W.'}}],
#  'total': 135,
#  'possible_languages': ['en']}

# %%
## turn JSON into usable data (DF)
yelp_gendf_reviews = pd.DataFrame(yelp_genjson_reviews['reviews'])
yelp_gendf_reviews
# Out:
#                        id                                                url  \
# 0  ZKw3pgptzE3aKiKmwFLK1Q  https://www.yelp.com/biz/sushiya-hanover-2?adj...
# 1  nzGzOK01t_DztjuYGwB4SQ  https://www.yelp.com/biz/sushiya-hanover-2?adj...
# 2  xfBpLVOxGF9UZAoe8wQpBw  https://www.yelp.com/biz/sushiya-hanover-2?adj...
#
#                                                 text  rating  \
# 0  Just had an phenomenal meal here and look forw...       5
# 1  This restaurant is now takeout only. The sushi...       3
# 2  Ordered takeout for 6 rolls. All of them taste...       4
#
#           time_created                                               user
# 0  2022-08-25 19:19:55  {'id': '76gvqovFuTpEoOHysjbY6w', 'profile_url'...
# 1  2022-10-17 18:15:08  {'id': 'trIbciU6PXfiXr0BYz0DQw', 'profile_url'...
# 2  2021-10-14 19:20:23  {'id': 'Imrkj1Ywx5RVNDmDh9AFcw', 'profile_url'...
